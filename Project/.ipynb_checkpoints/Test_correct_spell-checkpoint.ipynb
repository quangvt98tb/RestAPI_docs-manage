# %%
from tensorflow.keras.models import load_model

# %%
model_predict = load_model('spell_transfer.h5')

# %%
from tensorflow.keras.losses

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# -ensorflow                    2.4.1
# -ensorflow-gpu                2.4.1
# absl-py                       0.10.0
# aiofiles                      0.6.0
# aplus                         0.11.0
# appdirs                       1.4.4
# asgiref                       3.3.1
# astroid                       2.4.1
# astropy                       4.2
# astunparse                    1.6.3
# attrs                         19.3.0
# audioread                     2.1.9
# Automat                       20.2.0
# autopep8                      1.5.2
# backcall                      0.2.0
# beautifulsoup4                4.9.3
# bleach                        3.1.5
# blis                          0.7.4
# boto                          2.49.0
# boto3                         1.14.0
# botocore                      1.17.0
# bqplot                        0.12.22
# branca                        0.4.2
# ...
